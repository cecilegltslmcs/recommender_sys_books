# %% [markdown]
# # Recommender system for books: Cleaning and exploration

# %% [markdown]
# - Utils

# %%
# data manipulation libraries
import pandas as pd
import numpy as np
import missingno as msno

# graphical libraries
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud, STOPWORDS

# system libraries
import gc
import glob
import sys
sys.path.append("Modules/")

# nlp preprocessing module
import nlp_module as nlp
# Out:
# [nltk_data] Downloading package stopwords to /home/cecile/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# seaborn parameters
sns.set_theme(style="ticks",
              palette="Pastel2")

# %% [markdown]
# Before doing modelisation, datasets will be explored. Our data are presented in two datasets :
# - One about books
# - One about users
#
# The datasets were created by extracting information for Goodreads API. This API is desactivated since December 2020. Our data present information from 2013 to 2019.

# %% [markdown]
# ## 1) Exploring the books datasets

# %%
# importing different files and 
# concatenating in one dataset
filepath = 'Datasets/'

all_files = glob.glob(filepath + "books/*.csv")

li = []

for filename in all_files:
    df = pd.read_csv(filename)
    li.append(df)

merged_books = pd.concat(li,
                        axis=0,
                        ignore_index=True)
merged_books.head()
# Out:
#         Id                                               Name  \
# 0  4000000                                     Top Management
# 1  4000001                          Celtic Warfare, 1595 1763
# 2  4000002                                   Playwright Power
# 3  4000009                   Selected Topics In Harmonic Maps
# 4  4000010  Foreign Exchange Intervention: Objectives And ...
#
#                      Authors        ISBN  Rating  PublishYear  PublishMonth  \
# 0            Bernard  Taylor  0582446058    0.00         1973             1
# 1         James Michael Hill  0859761517    3.67         1986             1
# 2            Robert Friedman  0761803629    0.00         1996             7
# 3                James Eells  0821807005    0.00         1983             1
# 4  Sylvester C.W. Eijffinger  1858988128    0.00         1999             1
#
#    PublishDay                          Publisher RatingDist5  ... RatingDist3  \
# 0           1           Longman Publishing Group         5:0  ...         3:0
# 1           1                          J. Donald         5:1  ...         3:0
# 2          28        University Press of America         5:0  ...         3:0
# 3           1  American Mathematical Society(RI)         5:0  ...         3:0
# 4           1            Edward Elgar Publishing         5:0  ...         3:0
#
#   RatingDist2 RatingDist1 RatingDistTotal CountsOfReview  Language  \
# 0         2:0         1:0         total:0              0       NaN
# 1         2:1         1:0         total:3              0       NaN
# 2         2:0         1:0         total:0              0       NaN
# 3         2:0         1:0         total:0              0       NaN
# 4         2:0         1:0         total:0              0       NaN
#
#   PagesNumber                                        Description pagesNumber  \
# 0       448.0                                                NaN         NaN
# 1       203.0                                                NaN         NaN
# 2       164.0  Playwright Power is a concise handbook on how ...         NaN
# 3        85.0  Gives an account of the various aspects of the...         NaN
# 4       608.0  This collection of previously published articl...         NaN
#
#    Count of text reviews
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
#
# [5 rows x 21 columns]

# %% [markdown]
# As seen below, this dataset contains 21 columns. For each book, we have :
# - An Id, which is an artificial data created for database;
# - A name, which correspond to the title of the books;
# - Authors;
# - The ISBN, for more information about the ISBN (https://en.wikipedia.org/wiki/International_Standard_Book_Number);
# - Ratings, which correspond to the average rating for the book;
# - Informations about the date of publication;
# - Publisher;
# - Rating distance, which corresponds to the number of ratings for each score from 1 to 5;
# - Counts of review, which is the number of text reviews;
# - Language;
# - Number of pages;
# - Description.

# %%
# Identify missing values
msno.matrix(merged_books)
# Out:
# <AxesSubplot:>

# %% [markdown]
# We can show that we have two columns "PagesNumber" and they are complementary. We create an unique columns "NumberOfPages" in order to eliminate all the missing values.

# %%
merged_books["NumberOfPages"] = merged_books["PagesNumber"].fillna(0)\
                              + merged_books["pagesNumber"].fillna(0)

# %%
# deleting columns about publish day, month and ratingdists
merged_books.drop(["PublishMonth", "PublishDay",
                   "RatingDist5", "RatingDist4",
                   "RatingDist3", "RatingDist3",
                   "RatingDist2", "RatingDist1",
                   "RatingDistTotal", "Count of text reviews",
                   "PagesNumber", "pagesNumber"], axis=1,
                   inplace=True)

# %%
merged_books.head()
# Out:
#         Id                                               Name  \
# 0  4000000                                     Top Management
# 1  4000001                          Celtic Warfare, 1595 1763
# 2  4000002                                   Playwright Power
# 3  4000009                   Selected Topics In Harmonic Maps
# 4  4000010  Foreign Exchange Intervention: Objectives And ...
#
#                      Authors        ISBN  Rating  PublishYear  \
# 0            Bernard  Taylor  0582446058    0.00         1973
# 1         James Michael Hill  0859761517    3.67         1986
# 2            Robert Friedman  0761803629    0.00         1996
# 3                James Eells  0821807005    0.00         1983
# 4  Sylvester C.W. Eijffinger  1858988128    0.00         1999
#
#                            Publisher  CountsOfReview Language  \
# 0           Longman Publishing Group               0      NaN
# 1                          J. Donald               0      NaN
# 2        University Press of America               0      NaN
# 3  American Mathematical Society(RI)               0      NaN
# 4            Edward Elgar Publishing               0      NaN
#
#                                          Description  NumberOfPages
# 0                                                NaN          448.0
# 1                                                NaN          203.0
# 2  Playwright Power is a concise handbook on how ...          164.0
# 3  Gives an account of the various aspects of the...           85.0
# 4  This collection of previously published articl...          608.0

# %%
merged_books.dropna(inplace=True)

# %%
msno.matrix(merged_books)
# Out:
# <AxesSubplot:>

# %%
merged_books.shape
# Out:
# (145578, 11)

# %%
merged_books.isnull().mean() * 100
# Out:
# Id                0.0
# Name              0.0
# Authors           0.0
# ISBN              0.0
# Rating            0.0
# PublishYear       0.0
# Publisher         0.0
# CountsOfReview    0.0
# Language          0.0
# Description       0.0
# NumberOfPages     0.0
# dtype: float64

# %% [markdown]
# ### a) Numerical variables

# %% [markdown]
# In this part, we explore informations about numerical variables. These variables are the year of publication, the number of ratings and the average ratings of each books.

# %%
sns.boxplot(x="PublishYear",
            data=merged_books)
plt.show()

# %%
# dropping data where year of publication is 
# less than 1820 & more than 2019
ind = merged_books.loc[(merged_books["PublishYear"] <= 1820)\
                       | (merged_books["PublishYear"] >= 2019)].index\
                       .to_list()
merged_books.drop(index=ind,
                  inplace=True)

# %%
fig, axes = plt.subplots(1, 2,
                         figsize=(15, 5),
                         sharex=True)
fig.suptitle('Description of the year of publication of each book')

sns.histplot(ax=axes[0],
             x="PublishYear",
             data=merged_books,
             kde=True)
axes[0].set_title("Distribution of the year of publication")

sns.boxplot(ax=axes[1],
            x="PublishYear",
            data=merged_books)
axes[1].set_title("Boxplot of the year of publication")

plt.show()

# %% [markdown]
# After cleaning, only books with a year of publication between 1820 and 2019 were conserved. The majority of the books had been published between 1980 and 2019. The average is around 2000.

# %%
fig, axes = plt.subplots(1, 2,
                         figsize=(15, 5),
                         sharex=True)
fig.suptitle('Description of the number of reviews of each book')

sns.histplot(ax=axes[0],
             x="CountsOfReview",
             data=merged_books,
             kde=True)
axes[0].set_title("Distribution of the number of reviews")

sns.boxplot(ax=axes[1],
            x="CountsOfReview",
            data=merged_books)
axes[1].set_title("Boxplot of the number of reviews")

plt.show()

# %% [markdown]
# The number of reviews is between 0 and 160.000.

# %%
fig, axes = plt.subplots(1, 2, figsize=(15, 5), sharex=True)
fig.suptitle('Description of the average ratings of each book')

sns.histplot(ax=axes[0],
             x="Rating",
             data=merged_books,
             kde=True)
axes[0].set_title("Distribution of the average ratings")

sns.boxplot(ax=axes[1],
            x="Rating",
            data=merged_books)
axes[1].set_title("Boxplot of the average ratings")

plt.show()

# %% [markdown]
# Ratings are between 1 and 5. 0 contains all the books with no review. The mean rating is aroung 4.

# %% [markdown]
# ### b) Categorical variables

# %% [markdown]
# We examine the different categorical variables of our dataset. We represented Top 15 about Authors, Publishers and languages.

# %%
plt.figure(figsize=(7, 5))

sns.countplot(y="Authors",
              data=merged_books,
              order=merged_books["Authors"]\
              .value_counts()\
              .index[:15])

plt.title("Top 15 of the most read authors")
plt.show()

# %%
plt.figure(figsize=(7, 5))

sns.countplot(y="Publisher",
              data=merged_books,
              order=merged_books["Publisher"]\
              .value_counts()\
              .index[:15])

plt.title("Top 15 of the most present publishers")
plt.show()

# %%
plt.figure(figsize=(7, 5))

sns.countplot(y="Language",
              data=merged_books,
              order=merged_books["Language"]\
              .value_counts()\
              .index[:15])
plt.title("Top 15 of the most represented languages")
plt.show()

# %% [markdown]
# The different categories of English are united in one category: eng.

# %%
lang = {
    "en-US" : "eng",
    "en-GB" : "eng",
    "en-CA" : "eng"
}

# %%
for key, value in lang.items():
    merged_books["Language"]\
    .loc[merged_books["Language"]\
    .str.contains(key, 
                  case=False,
                  regex=False)] = value
# Out:
# /home/cecile/anaconda3/envs/nlpenv/lib/python3.9/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
plt.figure(figsize=(7, 5))

sns.countplot(y="Language",
              data=merged_books,
              order=merged_books["Language"]\
              .value_counts()\
              .index[:15])
              
plt.title("Top 15 of the most represented languages")
plt.show()

# %% [markdown]
# For this proof of concept, only books in English were keept.

# %%
merged_books_en = merged_books[merged_books["Language"] == "eng"]
merged_books_en.head()
# Out:
#           Id                                               Name  \
# 21   4000063                 The Flintstones in Viva Rock Vegas
# 36   4000100                                       Little Rhody
# 83   4000228  Finance And Investments Using The Wall Street ...
# 138  4000366                       Shorty McCabe Looks 'Em Over
# 168  4000441                                    Plant Pathology
#
#                  Authors        ISBN  Rating  PublishYear  \
# 21           Ellen Miles  0439173035    3.82         2000
# 36   Neta Lohnes Frazier  0679250808    4.33         2000
# 83        Peter R. Crabb  0072829362    0.00         2002
# 138          Sewell Ford  0836935357    0.00         1970
# 168     George N. Agrios  0120445646    4.52         1997
#
#                Publisher  CountsOfReview Language  \
# 21       Scholastic Inc.               1      eng
# 36   David McKay Company               1      eng
# 83     Irwin/McGraw-Hill               0      eng
# 138  Books for Libraries               0      eng
# 168       Academic Press               0      eng
#
#                                            Description  NumberOfPages
# 21   Spring 2000 marks the release of the new Flint...          136.0
# 36   A spunky ten-year-old girl moves with her fami...          152.0
# 83   Peter Crabb's The Wall Street Journal Workbook...          402.0
# 138  This is an EXACT reproduction of a book publis...          344.0
# 168  This is a classic textbook on plant diseases, ...          635.0

# %%
merged_books_en.to_parquet("Datasets/books_with_complete_description.parquet.gzip",
                compression="gzip",
                index=False)

# %% [markdown]
# ### c) Description of books analysis

# %% [markdown]
# Description of the books need a specific processing. The different steps of preprocessing are :
# - remote stopwords;
# - remote specific caracters;
# - expand contractions forms;
# - lemmatization.

# %%
desc = merged_books_en[["Id", "Description"]]
desc.head(3)
# Out:
#          Id                                        Description
# 21  4000063  Spring 2000 marks the release of the new Flint...
# 36  4000100  A spunky ten-year-old girl moves with her fami...
# 83  4000228  Peter Crabb's The Wall Street Journal Workbook...

# %%
desc["Description"] = nlp.normalize_corpus(desc["Description"])
# Out:
# /home/cecile/anaconda3/envs/nlpenv/lib/python3.9/site-packages/bs4/__init__.py:337: MarkupResemblesLocatorWarning: "." looks like a directory name, not markup. You may want to open a file found in this directory and pass the filehandle into Beautiful Soup.
#   warnings.warn(
# /home/cecile/anaconda3/envs/nlpenv/lib/python3.9/site-packages/bs4/__init__.py:337: MarkupResemblesLocatorWarning: ".." looks like a directory name, not markup. You may want to open a file found in this directory and pass the filehandle into Beautiful Soup.
#   warnings.warn(
# /tmp/ipykernel_4263/3132403736.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   desc["Description"] = nlp.normalize_corpus(desc["Description"])

# %%
desc.head(3)
# Out:
#          Id                                        Description
# 21  4000063  spring mark release new flintstone film flints...
# 36  4000100  spunky ten year old girl move family farm invo...
# 83  4000228  peter crabbs wall street journal workbook inve...

# %%
desc.to_parquet("Datasets/description.parquet.gzip",
                compression="gzip",
                index=False)

# %%
stopwords = set(STOPWORDS)
wordcloud = WordCloud(width = 800, height = 1000,
                max_words=1000,
                background_color ='white',
                stopwords = stopwords,
                min_font_size = 12,
                colormap="Set2").generate(str(desc["Description"]))
 
# plot the WordCloud image                      
plt.figure(figsize = (8, 8),
           facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)

# %%
merged_books_en.drop("Description",
                     axis=1,
                     inplace=True)
data = pd.merge(merged_books_en,
                desc,
                on="Id")
data.head(3)
# Out:
# /home/cecile/anaconda3/envs/nlpenv/lib/python3.9/site-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#         Id                                               Name  \
# 0  4000063                 The Flintstones in Viva Rock Vegas
# 1  4000100                                       Little Rhody
# 2  4000228  Finance And Investments Using The Wall Street ...
#
#                Authors        ISBN  Rating  PublishYear            Publisher  \
# 0          Ellen Miles  0439173035    3.82         2000      Scholastic Inc.
# 1  Neta Lohnes Frazier  0679250808    4.33         2000  David McKay Company
# 2       Peter R. Crabb  0072829362    0.00         2002    Irwin/McGraw-Hill
#
#    CountsOfReview Language  NumberOfPages  \
# 0               1      eng          136.0
# 1               1      eng          152.0
# 2               0      eng          402.0
#
#                                          Description
# 0  spring mark release new flintstone film flints...
# 1  spunky ten year old girl move family farm invo...
# 2  peter crabbs wall street journal workbook inve...

# %%
data.drop("Language",
           axis=1,
           inplace=True)

# %%
data.to_parquet("Datasets/books_data_cleaning.parquet.gzip",
                 compression="gzip",
                 index=False)

# %%
del data,\
    merged_books,\
    merged_books_en
gc.collect()
# Out:
# 26211087

# %% [markdown]
# ## 2) Exploring the users datasets

# %% [markdown]
# After exploring datasets about books, it is time to explore datasets about users.

# %%
book_data = pd.read_parquet("Datasets/books_data_cleaning.parquet.gzip")

# %%
# importing different files and 
# concatenating in one dataset
filepath = 'Datasets/'

all_files = glob.glob(filepath\
          + "users_ratings/*.csv")

li = []

for filename in all_files:
    df = pd.read_csv(filename)
    li.append(df)

merged_users = pd.concat(li,
                         axis=0,
                         ignore_index=True)
merged_users.head()
# Out:
#      ID    Name                             Rating
# 0  5410  Rating  This user doesn't have any rating
# 1  5411  Rating  This user doesn't have any rating
# 2  5412  Rating  This user doesn't have any rating
# 3  5416  Rating  This user doesn't have any rating
# 4  5417  Rating  This user doesn't have any rating

# %%
# Identify missing values
msno.matrix(merged_users)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Ratings are comments already written. In a first step, comments are modified into numbers. After this modification, missing values are dropping from our dataset. !

# %%
merged_users["Rating"].unique()
# Out:
# array(["This user doesn't have any rating", 'really liked it', 'liked it',
#        'it was amazing', 'it was ok', 'did not like it'], dtype=object)

# %%
new_ratings ={
    "This user doesn't have any rating" : np.nan,
    "did not like it" : 1,
    "it was ok" : 2,
    "liked it" : 3,
    "really liked it" : 4,
    "it was amazing" : 5
}

merged_users["Rating"] = merged_users["Rating"].map(new_ratings)

# %%
merged_users.columns = ['User_Id', "Name", "Rating"]

# %%
# Identify missing values
msno.matrix(merged_users)
# Out:
# <AxesSubplot:>

# %%
merged_users.dropna(inplace=True)

# %% [markdown]
# #### Categorical variables analysis

# %% [markdown]
# Top 15 of the most active users and the top 15 of the books with the most ratings were represented below.

# %%
plt.figure(figsize=(7, 5))

sns.countplot(y="User_Id",
              data=merged_users,
              order=merged_users["User_Id"].value_counts().index[:15])
plt.ylabel("User Id")
plt.title("Top 15 of the users that made the most ratings")
plt.show()

# %%
plt.figure(figsize=(7, 5))

sns.countplot(y="Name",
              data=merged_users,
              order=merged_users["Name"].value_counts().index[:15])
plt.ylabel("Title of the book")
plt.title("Top 15 of the books that had the most ratings")
plt.show()

# %%
book_data = book_data[["Id","Name", "Authors"]]

# %%
rating_merged = pd.merge(merged_users,
                         book_data,
                         on = "Name")
rating_merged.head()
# Out:
#    User_Id             Name  Rating      Id         Authors
# 0     5433  Of Mice and Men     4.0  810433  John Steinbeck
# 1     5473  Of Mice and Men     4.0  810433  John Steinbeck
# 2     5491  Of Mice and Men     3.0  810433  John Steinbeck
# 3     5499  Of Mice and Men     3.0  810433  John Steinbeck
# 4     5527  Of Mice and Men     3.0  810433  John Steinbeck

# %%
rating_merged.drop(["Name", "Authors"],
                    axis=1, 
                    inplace=True, )

# %%
rating_merged.to_parquet("Datasets/users_data_cleaning.parquet.gzip",
                compression="gzip",
                index=False)

# %% [markdown]
# ## Conclusion

# %% [markdown]
# After cleaning and selecting, our datasets contains informations of 140.000 english books and 360.000 ratings. Choice of keeping English books was made because of the preprocessing of each description. Nevertheless, some steps of preprocessing such as removing stopwords or lemmatisation are language specific. In the future, it can be interesting to add informations of French and German books.
# Informations about books are name(title), authors, publications' information, description, ratings and number of pages. It can be interesting to have the genre of each book in order to improve the performance of our recommendation system.
